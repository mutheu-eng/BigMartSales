# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
path = 'C:/Users/user/Downloads/BigMartSales'
train =pd.read_csv('train.csv')

# %%
train.head(10)
# Out:
#   Product_id  Product_Weight Product_Fat_Content  Product_Visibility  \
# 0      FDA15           9.300             Low Fat            0.016047
# 1      DRC01           5.920             Regular            0.019278
# 2      FDN15          17.500             Low Fat            0.016760
# 3      FDX07          19.200             Regular            0.000000
# 4      NCD19           8.930             Low Fat            0.000000
# 5      FDP36          10.395             Regular            0.000000
# 6      FDO10          13.650             Regular            0.012741
# 7      FDP10             NaN             Low Fat            0.127470
# 8      FDH17          16.200             Regular            0.016687
# 9      FDU28          19.200             Regular            0.094450
#
#             Product_Type  Product_MRP Store_Identifier  \
# 0                  Dairy     249.8092           OUT049
# 1            Soft Drinks      48.2692           OUT018
# ...

# %%
product_mean = train.groupby('Product_Type')['Product_Weight'].mean() 

def replace_weight_with_mean(row):
    if pd.isnull(row['Product_Weight']):
        return product_mean[row['Product_Type']]
    else:
        return row['Product_Weight']
    
train['Product_Weight'] = train.apply(replace_weight_with_mean, axis=1)

# %%
train.head(10)
# Out:
#   Product_id  Product_Weight Product_Fat_Content  Product_Visibility  \
# 0      FDA15         9.30000             Low Fat            0.016047
# 1      DRC01         5.92000             Regular            0.019278
# 2      FDN15        17.50000             Low Fat            0.016760
# 3      FDX07        19.20000             Regular            0.000000
# 4      NCD19         8.93000             Low Fat            0.000000
# 5      FDP36        10.39500             Regular            0.000000
# 6      FDO10        13.65000             Regular            0.012741
# 7      FDP10        12.98788             Low Fat            0.127470
# 8      FDH17        16.20000             Regular            0.016687
# 9      FDU28        19.20000             Regular            0.094450
#
#             Product_Type  Product_MRP Store_Identifier  \
# 0                  Dairy     249.8092           OUT049
# 1            Soft Drinks      48.2692           OUT018
# ...

# %%
train.Store_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Store_Size, dtype: int64

# %%
train['Store_Size'].fillna('Medium',inplace=True)

# %%
df = pd.read_csv('sales_data.csv')

# %%
df['Product_Fat_Content'].replace({'LF': 'Low Fat', 'reg': 'Regular'}, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
'''
# Visualization for Product Fat Content
plt.figure(figsize=(8, 6))
plt.barh(y='Product_Fat_Content', width='Sales', data=df)
plt.title('Sales by Product Fat Content')
plt.xlabel('Total Sales')
plt.ylabel('Product Fat Content')
plt.show()

Visualization for Product Type
plt.figure(figsize=(12, 8))
sns.barplot(x='Product_Type', y='Sales', data=df)
plt.title('Sales by Product Type')
plt.xlabel('Product Type')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# Visualization for Store Size
plt.figure(figsize=(8, 6))
plt.barh(y='Store_Size', width='Sales', data=df)
plt.title('Sales by Store Size')
plt.xlabel('Store Size')
plt.ylabel('Total Sales')
plt.show()

# Visualization for Store Tier
plt.figure(figsize=(8, 6))
sns.barplot(x='Store_Location_Type', y='Sales', data=df)
plt.title('Sales by Location')
plt.xlabel('Store Location')
plt.ylabel('Total Sales')
plt.show()
'''
# Visualization for Store Type
plt.figure(figsize=(10, 8))
sns.barplot(x='Store_Type', y='Sales', data=df)
plt.title('Sales by Store Type')
plt.xlabel('Store Type')
plt.ylabel('Total Sales')
plt.show()
